# %%
from pixell import enmap,utils, reproject, enplot
import numpy as np
import matplotlib.pyplot as plt
import os,sys
from scipy.interpolate import interp1d
import math
import pandas as pd
import pickle as pk
import h5py
import time
from astropy import wcs
from astropy.coordinates import SkyCoord  # High-level coordinates
from astropy.coordinates import ICRS, Galactic, FK4, FK5  # Low-level frames
from astropy.coordinates import Angle, Latitude, Longitude  # Angles
import astropy.units as u
from astropy.io import fits
from astropy.table import QTable
import astropy.table as tb 
from astropy.time import Time 
from astroquery.jplhorizons import Horizons

import re
from numba import jit

# %%
@jit(nopython=True)
def strange_check(strange_handles, target):
    #A small helper function that finds the index of our target plannet. Due to a difference 
    #in naming scheme we unfortunately can't just use np.where or something like that
    for i in range(len(strange_handles)):
        if strange_handles[i] == target:
            break
            
    return i

def tnoStamp(ra, dec, imap, width = 0.5):
    #Takes an individual stamp of a map at the requested ra/dec. We form the ratio later  
    #frhs is a matched filter map and kmap is the inverse variance per pixel
    #both maps are at a ~3 day cadence

    #Inputs: ra, dec in degrees, j2000
    #kmap or frhs, described above. They must have the same wcs
    #but if you're using this code and sigurd's maps they will
    #width, the desired width of the stamp in degrees

    #Output: a stamp, centered on ra/dec, with width width, where
    #each pixel in the map records the S/N. This stamp is for one
    #object, one 3 day map. These must then be stacked for each object
    #and then the objects can be stacked together

    #Find the pixel 
    coords = np.deg2rad(np.array((dec,ra)))
    ypix,xpix = enmap.sky2pix(imap.shape,imap.wcs,coords)
        
    #nans are formed when try to form S/n for pixels with no hits
    #I just set the S/N to 0 which I think is safe enough
    imap[~np.isfinite(imap)] = 0

    #Reproject will attempt to take a stamp at the desired location: if it can't
    #for whatever reason just return None. We don't want it throwing errors
    #while on the wall, however the skips should probably be checked after
    #try:
    stamp = reproject.thumbnails(imap, [coords])
    #except:
    #    return None
    
    return stamp

class OrbitInterpolator:
    '''
    Constructs a class that can predict, using an interpolation scheme, the location of an object given an identifier and time
    '''
    def __init__(self, table):
        '''
        Requires a table generated from astroquery, querying JPL HORIZONS. The 
        interpolation is done automatically, but, of course, only works
        if the table is sampled densely enough and in the time range for which
        the positions were queried
        '''
        self.table = table
        self.targets = np.unique(table['targetname'])

        self._construct_dictionary()

    def _interpolate_radec(self, target):
        '''
        "Hidden" function that constructs the interpolations for each target
        '''        
        table = self.table[self.table['targetname'] == target]
        zero = np.min(table['datetime_jd'])
        ra_interp = interp1d(table['datetime_jd'] - zero, table['RA'])
        dec_interp = interp1d(table['datetime_jd'] - zero, table['DEC'])
        delta_interp = interp1d(table['datetime_jd'] - zero, table['delta'])

        return zero, ra_interp, dec_interp, delta_interp

    def _construct_dictionary(self):
        '''
        "Hidden" function that creates the look-up dictionary of targets for simplicity of usage
        '''
        self.obj_dic = {}
            
        for j,i in enumerate(self.targets):
            z, r, d, delta = self._interpolate_radec(i)
            self.obj_dic[i] = {}
            self.obj_dic[i]['zero'] = z
            self.obj_dic[i]['RA'] = r
            self.obj_dic[i]['DEC'] = d
            self.obj_dic[i]['delta'] = delta

    def get_radec_dist(self, target, time):
        '''
        Specifying a target name (see self.obj_dic.keys() for a list of targets) and a time (in JD), finds
        the interpolated RA and Dec for the objects
        '''
        time = time + 2400000.5

        t_intep = time - self.obj_dic[target]['zero']
        
        ra = self.obj_dic[target]['RA'](t_intep)
        dec = self.obj_dic[target]['DEC'](t_intep)
        dist = self.obj_dic[target]['delta'](t_intep)

        return ra, dec, dist

class QueryHorizons:
    '''
    Constructs a class that can query a bunch of positions for objects from JPL-Horizons given a set of times and an observatory location
    '''

    def __init__(self, time_start, time_end, observer_location, step = '1d'):
        '''
        Initialization function

        Arguments:
        - time_start: start time for the query, should be in MJD
        - time_end: end time for the query, should be in MJD
        - observer_location: location of the observer
        - step: time step for the ephemeris
        The simples way to get the observer location variable is via the
        list of IAU observatory codes: https://en.wikipedia.org/wiki/List_of_observatory_codes
        
        Custom locations are also accepted by JPL
        '''
        if type(time_start) == str: 
            t_st = Time(time_start, format='isot', scale='utc')
            
        else: 
            t_st = Time(time_start, format='mjd')
        self.time_start = t_st.utc.iso  
        if type(time_end) == str: 
            t_en = Time(time_end, format='isot', scale='utc')
            
        else: 
            t_en = Time(time_end, format='mjd')
            
        self.time_end = t_en.utc.iso 
        
        self.observer = observer_location

        self.step = step 


    def queryObjects(self, objects):
        '''
        Returns a table (and saves it on the object as well) for the provided list of objects
        '''
        self.table = [] 

        for i in objects:
            query = Horizons(id = i, location = self.observer, 
                epochs = {'start' : self.time_start, 'stop' : self.time_end, 'step' : self.step})

            eph = query.ephemerides()

            self.table.append(eph['RA', 'DEC', 'datetime_jd', 'targetname', 'delta', 'r'])
        
        self.table = tb.vstack(self.table)

        return self.table


def tnoStacker(oribits_obj, obj):
    #Returns a stack over ~~~1~~~ objects orbit
    
    #Inputs, orbits, and OrbitInterpolator instance, which contains all the orits of interest, i.e. for multiple objects
    #obj, the name/id of the object of interest
    
    #Path to the maps. Probably shouldn't be hard coded
   
    print('stacking on ', str(obj))

    path = '/home/r/rbond/sigurdkn/scratch/actpol/planet9/20200801/maps/combined/'
    
    #path = '/global/cscratch1/sd/jorlo/three_day_maps/'
    
    #Initialize stack/divisor
    kstack = 0
    fstack = 0
   
    
    #Get the index of the tno we're working with
    #tno_hdu = fits.open('/project/r/rbond/jorlo/act_tnos/dist_h_y4.fits')
    #tno_data = tno_hdu[1].data


    #we're now going to check each directory in the path, each of which corresponds to one
    #~3 day coadd
    for i, dirname in enumerate(os.listdir(path=path)):
        #if i>10: break
        print('In dir ', dirname)
        try:
            with h5py.File(path + dirname +"/info.hdf", "r") as hfile:
                #Find the (rough) mjd center of the map
                mjd_cent = hfile["mjd"][()]
                
        except:
            print('no info file in ', dirname)
            continue
        #Get the ra/dec of the object, as well as delta, the geocentric distance to the object
        #We use geocentric as we're looking at the IR emission, which scales as r**2 the distance
        #from the obj to earth. If we were looking at reflected sunlight, we'd care about the heliocentric
        ra, dec, delta = oribits_obj.get_radec_dist(obj, mjd_cent)

        #Get wcs info from the kmap for this 3day coadd: for sigurd's maps the kmap and 
        #frhs map wcs info will be the same
        hdu = fits.open(path + dirname + '/kmap.fits')
        w = wcs.WCS(hdu[0].header)
        
        #Find pixel corresponding to our ra/dec. I actually can no longer recall why
        #I did this and it doesn't seem to do anything so it could probably be
        #removed
        c = SkyCoord(ra, dec, unit="deg")
        x, y = w.world_to_pixel(c)
        
        #Read in the maps and take the stamp using tnoStamp
        kmap = enmap.read_map(path + dirname + '/kmap.fits')
        try:
            frhs = enmap.read_map(path + dirname + '/frhs.fits')
        except:
            print('frhs too big')
            continue
            
        kstamp = tnoStamp(ra, dec, kmap)
        fstamp = tnoStamp(ra, dec, frhs)
        #See tnoStamp but if stamp is None it means something went wrong.
        #We also check to see if the maps are uniformly zero 
       
        if (kstamp is None) or (fstamp is None):
            continue
        if (not np.any(kstamp[0])) or (not np.any(fstamp[0])):
            continue
        #if np.any(np.isinf(stamp[0])):
        #    continue

        #Scale by the flux compared to the reference flux at 1AU
        flux_scale = (delta/1)**2 #Div one just a placeholder for ref scale
        #flux_scale = 1
                    

        #Stack it up, divide and return
        fstack += fstamp[0]/flux_scale
        kstack += kstamp[0]/flux_scale**2
        #print(stack)
        

    flux_stack = fstack/kstack

    return np.array(flux_stack), np.array(fstack), np.array(kstack), np.array(flux_scale)

class minorplanet():
    '''
    Constructs a class that includes everything we want to do with a minor planet
    '''
    def __init__(self, name, obs = 'W99', t_start ='2010-01-01T00:00:00', t_end='2020-01-01T00:00:00'):
        '''
        Requires a name for the object, as well as an observatory code which can be found at
        https://en.wikipedia.org/wiki/List_of_observatory_codes
        See the QueryHorizons class for full details of observatory code options
        '''
        self.name = name
        self.obs = obs
        
        self.t_start = t_start
        self.t_end = t_end
        
        #We interpolate the orbit for the minor planet at initialization as it's fairly fast
        #Stacking is a method as it is much slower so we want to call it only when we actually care
        self.eph_table = QueryHorizons(time_start=self.t_start, time_end=self.t_end, 
                                       observer_location=obs, step = '1d').queryObjects([str(self.name)])
        
        self.interp_orbit = OrbitInterpolator(self.eph_table)
        
    
    def show_orbit(self, t_orb_start = '2013-01-01T00:00:00', t_orb_end = '2020-01-01T00:00:00', 
                   directory = None):
        '''
        Function that plots the orbit of the minor planet from t_orb_start to t_orb_end
        '''
        
        t_start = Time(t_orb_start, format='isot', scale='utc')
        t_start = t_start.mjd

        t_en = Time(t_orb_end, format='isot', scale='utc')
        t_en = t_en.mjd
        mjds = np.linspace(t_start, t_en, 1000)

        ras, decs, delts = self.interp_orbit.get_radec_dist(self.eph_table['targetname'][0], mjds)

        plt.plot(ras, decs)
        plt.xlabel('ra')
        plt.ylabel('dec')
        plt.title('Orbital Plot of {}'.format(self.eph_table['targetname'][0]))
        if directory is not None:
            plt.savefig(directory+'{}_orbit.pdf'.format(str(self.eph_table['targetname'][0]).replace(' ', '_').replace('(','').replace(')','')))
        plt.show()
        plt.close()
        
    def make_stack(self):
        self.flux_stack, self.fstack, self.kstack, self.flux_scale = tnoStacker(self.interp_orbit,self.eph_table['targetname'][0])

    def save_stack(self, pk_dir):
        aster_dict = {'flux_stack':self.flux_stack, 'fstack':self.fstack, 'kstack':self.kstack, 'flux_scale':self.flux_scale}
        with open(pk_dir+'{}_stamp.pk'.format(str(self.eph_table['targetname'][0]).replace(' ', '_').replace('(','').replace(')','')), 'wb') as f:
            pk.dump(aster_dict, f)
            
    def plot_stack(self, directory = None):
        plt.imshow(flux_stack)
        plt.xlabel('ra')
        plt.ylabel('dec')
        plt.title('Plot of {} Stack'.format(self.eph_table['targetname'][0]))
        if directory is not None:
            plt.savefig(directory + '{}_stamp.pdf'.format(str(self.eph_table['targetname'][0]).replace(' ', '_').replace('(','').replace(')','')))
        plt.show()

# %%
europa = minorplanet('Europa')
europa.make_stack()
# Out:
# stacking on  52 Europa (A858 CA)
# In dir  s18_cmb_1536796800
# In dir  s18_cmb_1542240000
# In dir  s15_deep8_1437523200
# In dir  s15_deep9_1435449600
# In dir  s16_cmb_1476921600
# In dir  s15_deep9_1442707200
# In dir  s15_deep56_1451001600
# In dir  s19_cmb_1556755200
# In dir  s13_deep2_1383350400
# In dir  s15_deep8_1447372800
# In dir  s13_deep5_1387497600
# In dir  s15_deep9_1439596800
# In dir  s15_deep9_1438300800
# In dir  s15_deep8_1439337600
# In dir  s19_cmb_1564272000
# In dir  s13_deep5_1381795200
# In dir  s15_boss_1438819200
# In dir  s15_deep9_1442966400
# In dir  s13_deep6_1380499200
# In dir  s15_deep8_1432857600
# In dir  s13_deep1_1378944000
# In dir  s16_cmb_1480032000
# In dir  s13_deep1_1383609600
# In dir  s13_deep6_1387497600
# In dir  s19_cmb_1572566400
# In dir  s16_cmb_1471737600
# In dir  s15_deep56_1446595200
# In dir  s16_cmb_1478995200
# In dir  s15_deep8_1444521600
# In dir  s15_deep9_1433635200
# In dir  s18_cmb_1525651200
# In dir  s16_cmb_1478217600
# In dir  s18_cmb_1544054400
# In dir  s19_cmb_1561420800
# In dir  s13_deep6_1384646400
# In dir  s13_deep1_1384387200
# In dir  s16_cmb_1474848000
# In dir  s14_deep56_1418342400
# In dir  s15_deep8_1433635200
# In dir  s18_cmb_1541721600
# In dir  s15_boss_1434412800
# In dir  s19_cmb_1571529600
# In dir  s16_cmb_1479772800
# In dir  s14_boss_1417824000
# In dir  s14_deep56_1412380800
# In dir  s17_cmb_1501286400
# In dir  s13_deep5_1385424000
# In dir  s16_day_14h_n_1477699200
# In dir  s15_deep8_1438560000
# In dir  s16_cmb_1477180800
# In dir  s13_deep1_1382572800
# In dir  s19_cmb_1565308800
# In dir  s15_deep9_1434153600
# In dir  s14_deep56_1416009600
# In dir  s15_boss_1435449600
# In dir  s15_boss_1446854400
# In dir  s15_boss_1448150400
# In dir  s15_deep8_1445817600
# In dir  s13_deep6_1383091200
# In dir  s19_cmb_1566864000
# In dir  s19_cmb_1568937600
# In dir  s15_deep56_1442188800
# In dir  s15_deep8_1441929600
# In dir  s15_deep56_1436227200
# In dir  s19_cmb_1572825600
# In dir  s16_day_14h_n_1475884800
# In dir  s13_deep5_1382313600
# In dir  s13_deep5_1381276800
# In dir  s15_boss_1429747200
# In dir  s13_deep6_1381017600
# In dir  s19_cmb_1569196800
# In dir  s13_deep2_1386460800
# In dir  s15_boss_1443744000
# In dir  s15_deep56_1435449600
# In dir  s19_cmb_1566345600
# In dir  s16_day_14h_n_1474848000
# In dir  s19_cmb_1575936000
# In dir  s14_boss_1413936000
# In dir  s15_deep9_1434931200
# In dir  s15_deep8_1446854400
# In dir  s14_boss_1417564800
# In dir  s17_cmb_1507248000
# In dir  s16_day_02h_s_1472256000
# In dir  s15_deep8_1443484800
# In dir  s19_cmb_1576454400
# In dir  s13_deep2_1381795200
# In dir  s19_cmb_1564790400
# In dir  s13_deep6_1379462400
# In dir  s16_day_02h_s_1473811200
# In dir  s19_cmb_1573344000
# In dir  s14_boss_1416528000
# In dir  s15_deep8_1439078400
# In dir  s17_cmb_1504915200
# In dir  s15_deep8_1437782400
# In dir  s16_day_02h_s_1465516800
# In dir  s15_deep8_1434412800
# In dir  s15_deep56_1431820800
# In dir  s14_deep56_1419897600
# In dir  s15_deep56_1446336000
# In dir  s14_boss_1414713600
# no info file in  s14_boss_1414713600
# In dir  s14_boss_1408752000
# In dir  s15_deep56_1436745600
# In dir  s17_cmb_1509840000
# In dir  s15_deep56_1434153600
# In dir  s16_day_02h_s_1464739200
# In dir  s14_boss_1415750400
# In dir  s17_cmb_1505692800
# In dir  s16_day_14h_n_1481328000
# In dir  s18_cmb_1527984000
# In dir  s16_cmb_1481068800
# In dir  s13_deep6_1378684800
# In dir  s19_cmb_1561161600
# In dir  s16_day_14h_n_1473811200
# In dir  s15_deep9_1432857600
# In dir  s13_deep1_1379980800
# In dir  s15_deep8_1435449600
# In dir  s13_deep5_1380240000
# In dir  s16_day_14h_n_1464998400
# In dir  s19_cmb_1575676800
# In dir  s13_deep5_1387238400
# In dir  s15_deep8_1443744000
# In dir  s15_deep8_1442448000
# In dir  s15_boss_1446336000
# In dir  s13_deep5_1379462400
# In dir  s15_deep56_1450224000
# In dir  s19_cmb_1564012800
# In dir  s15_deep8_1432080000
# In dir  s16_day_14h_n_1477440000
# In dir  s19_cmb_1551571200
# In dir  s19_cmb_1570752000
# In dir  s13_deep1_1383868800
# In dir  s15_deep56_1451520000
# In dir  s15_boss_1451520000
# In dir  s15_boss_1431820800
# In dir  s17_cmb_1516320000
# In dir  s15_boss_1437523200
# In dir  s17_cmb_1511654400
# In dir  s15_boss_1432857600
# In dir  s17_cmb_1501027200
# In dir  s15_deep56_1432339200
# In dir  s14_deep56_1413417600
# In dir  s16_cmb_1474588800
# In dir  s15_boss_1430265600
# In dir  s19_cmb_1552867200
# In dir  s13_deep1_1379721600
# In dir  s15_deep56_1441670400
# In dir  s13_deep2_1378684800
# In dir  s15_deep56_1434412800
# In dir  s13_deep6_1383868800
# In dir  s16_day_02h_s_1478476800
# In dir  s15_boss_1435190400
# In dir  s14_deep56_1408752000
# In dir  s16_cmb_1481328000
# In dir  s15_boss_1431561600
# In dir  s15_boss_1449964800
# In dir  s13_deep5_1378944000
# In dir  s19_cmb_1560124800
# In dir  s15_boss_1451779200
# In dir  s15_deep56_1439596800
# In dir  s13_deep2_1382054400
# In dir  s15_deep56_1435708800
# In dir  s16_cmb_1480550400
# In dir  s15_deep9_1436227200
# In dir  s15_boss_1451260800
# In dir  s16_cmb_1478736000
# In dir  s15_boss_1439337600
# In dir  s13_deep5_1383609600
# In dir  s15_deep8_1450742400
# In dir  s15_deep9_1439078400
# In dir  s18_cmb_1539648000
# In dir  s14_deep56_1414454400
# In dir  s15_boss_1445558400
# In dir  s19_cmb_1563235200
# In dir  s13_deep2_1382832000
# In dir  s14_boss_1410307200
# In dir  s13_deep6_1384128000
# In dir  s15_deep8_1442966400
# In dir  s14_deep56_1416528000
# In dir  s15_deep56_1433635200
# In dir  s19_cmb_1572048000
# In dir  s14_boss_1413676800
# In dir  s13_deep5_1384128000
# In dir  s15_boss_1446076800
# In dir  s17_cmb_1505952000
# In dir  s16_day_14h_n_1479772800
# In dir  s15_deep9_1437523200
# In dir  s14_deep56_1419638400
# In dir  s16_day_02h_s_1477699200
# In dir  s19_cmb_1570492800
# In dir  s17_cmb_1506988800
# In dir  s18_cmb_1537833600
# In dir  s19_cmb_1551830400
# In dir  s13_deep5_1384387200
# In dir  s14_boss_1411862400
# In dir  s13_deep1_1384646400
# In dir  s15_deep9_1439337600
# In dir  s13_deep6_1384905600
# In dir  s13_deep1_1386720000
# In dir  s15_deep56_1447632000
# In dir  s15_deep9_1442188800
# In dir  s16_cmb_1476403200
# In dir  s15_boss_1441670400
# In dir  s19_cmb_1575417600
# In dir  s19_cmb_1572307200
# In dir  s15_deep9_1431561600
# In dir  s16_day_14h_n_1482364800
# In dir  s17_cmb_1504396800
# In dir  s16_cmb_1465516800
# In dir  s16_day_14h_n_1480291200
# In dir  s15_deep56_1443225600
# In dir  s13_deep5_1379721600
# In dir  s16_day_02h_s_1471219200
# In dir  s17_cmb_1499731200
# In dir  s19_cmb_1556236800
# In dir  s17_cmb_1513468800
# In dir  s13_deep2_1383868800
# In dir  s19_cmb_1566604800
# In dir  s15_deep9_1435708800
# In dir  s19_cmb_1554422400
# In dir  s13_deep2_1383609600
# In dir  s16_cmb_1474070400
# In dir  s15_deep8_1452038400
# In dir  s13_deep1_1381017600
# In dir  s17_cmb_1499990400
# In dir  s13_deep6_1379721600
# In dir  s14_deep56_1412640000
# In dir  s18_cmb_1538352000
# In dir  s15_deep56_1436486400
# In dir  s15_deep56_1430784000
# In dir  s15_deep8_1434153600
# In dir  s13_deep5_1381536000
# In dir  s19_cmb_1561680000
# In dir  s18_cmb_1538870400
# In dir  s15_deep8_1438819200
# In dir  s13_deep1_1384905600
# In dir  s15_deep8_1434931200
# In dir  s15_boss_1443484800
# In dir  s15_deep9_1438041600
# In dir  s19_cmb_1564531200
# In dir  s16_cmb_1473033600
# In dir  s14_boss_1418342400
# In dir  s14_boss_1417305600
# In dir  s16_day_14h_n_1480809600
# In dir  s15_boss_1433894400
# In dir  s15_deep56_1449705600
# In dir  s17_cmb_1500249600
# In dir  s19_cmb_1553126400
# In dir  s18_cmb_1544313600
# In dir  s13_deep1_1387497600
# In dir  s13_deep1_1382054400
# In dir  s13_deep5_1383868800
# In dir  s15_deep56_1441929600
# In dir  s15_boss_1446595200
# In dir  s14_deep56_1415750400
# In dir  s17_cmb_1506211200
# In dir  s13_deep6_1386979200
# In dir  s16_day_02h_s_1471478400
# In dir  s15_deep56_1431302400
# In dir  s16_cmb_1481846400
# In dir  s15_deep56_1439078400
# In dir  s19_cmb_1573603200
# In dir  s13_deep5_1379980800
# In dir  s13_deep1_1381276800
# In dir  s19_cmb_1552608000
# In dir  s15_deep56_1450742400
# In dir  s18_cmb_1543276800
# In dir  s14_deep56_1409011200
# In dir  s19_cmb_1551312000
# In dir  s18_cmb_1537315200
# In dir  s17_cmb_1510099200
# In dir  s14_deep56_1418083200
# In dir  s15_boss_1441929600
# In dir  s15_deep8_1444780800
# In dir  s16_cmb_1479513600
# In dir  s13_deep6_1385164800
# In dir  s13_deep1_1379462400
# In dir  s13_deep2_1386979200
# In dir  s15_boss_1432080000
# In dir  s15_deep8_1430784000
# In dir  s19_cmb_1553644800
# In dir  s16_cmb_1475625600
# In dir  s16_cmb_1475366400
# In dir  s15_boss_1436486400
# In dir  s13_deep6_1378944000
# In dir  s19_cmb_1569715200
# In dir  s16_day_14h_n_1478736000
# In dir  s15_deep8_1437264000
# In dir  s15_deep56_1432857600
# In dir  s16_cmb_1472774400
# In dir  s13_deep1_1386201600
# In dir  s15_deep8_1433116800
# In dir  s13_deep1_1386979200
# In dir  s13_deep6_1387238400
# In dir  s16_cmb_1481587200
# In dir  s16_day_14h_n_1482105600
# In dir  s15_deep8_1439596800
# In dir  s15_deep8_1435968000
# In dir  s15_deep56_1444780800
# In dir  s17_cmb_1511913600
# In dir  s19_cmb_1556496000
# In dir  s14_deep56_1412121600
# In dir  s13_deep5_1382572800
# In dir  s15_boss_1452297600
# In dir  s15_deep9_1434672000
# In dir  s16_day_02h_s_1480291200
# In dir  s14_boss_1419638400
# In dir  s19_cmb_1571788800
# In dir  s16_day_02h_s_1481846400
# In dir  s15_deep8_1451779200
# In dir  s17_cmb_1503100800
# In dir  s16_day_14h_n_1479254400
# In dir  s19_cmb_1574380800
# In dir  s16_day_14h_n_1476921600
# In dir  s19_cmb_1553385600
# In dir  s15_deep8_1434672000
# In dir  s13_deep1_1387238400
# In dir  s15_deep8_1431820800
# In dir  s15_deep9_1441670400
# In dir  s15_deep56_1431043200
# In dir  s13_deep1_1381536000
# In dir  s19_cmb_1560384000
# In dir  s15_deep56_1452038400
# In dir  s13_deep2_1382572800
# In dir  s15_deep56_1430265600
# In dir  s15_deep9_1432080000
# In dir  s15_boss_1449446400
# In dir  s13_deep6_1379980800
# In dir  s15_deep8_1449705600
# In dir  s19_cmb_1571270400
# In dir  s17_cmb_1513728000
# In dir  s14_deep56_1409529600
# In dir  s13_deep5_1382054400
# In dir  s18_cmb_1528243200
# In dir  s13_deep1_1382313600
# In dir  s17_cmb_1505433600
# In dir  s13_deep2_1382313600
# In dir  s15_deep8_1446076800
# In dir  s16_day_14h_n_1465257600
# In dir  s16_day_02h_s_1478736000
# In dir  s15_deep56_1448409600
# In dir  s19_cmb_1574899200
# In dir  s15_deep9_1431820800
# In dir  s15_deep8_1435190400
# In dir  s19_cmb_1555459200
# In dir  s19_cmb_1562198400
# In dir  s13_deep6_1385683200
# In dir  s13_deep6_1381276800
# In dir  s16_day_02h_s_1479254400
# In dir  s13_deep6_1379203200
# In dir  s17_cmb_1495065600
# In dir  s14_deep56_1413676800
# In dir  s19_cmb_1555718400
# In dir  s19_cmb_1576195200
# In dir  s14_boss_1409011200
# In dir  s15_deep9_1436486400
# In dir  s13_deep1_1385164800
# In dir  s16_cmb_1475107200
# In dir  s16_day_02h_s_1481328000
# In dir  s19_cmb_1560902400
# In dir  s15_deep8_1447891200
# In dir  s17_cmb_1509580800
# In dir  s17_cmb_1510358400
# In dir  s16_day_02h_s_1464220800
# In dir  s13_deep2_1381536000
# In dir  s13_deep1_1384128000
# In dir  s17_cmb_1507507200
# In dir  s16_cmb_1464998400
# In dir  s13_deep2_1385683200
# In dir  s18_cmb_1542758400
# In dir  s13_deep6_1385424000
# In dir  s17_cmb_1501804800
# In dir  s16_cmb_1471478400
# In dir  s16_cmb_1480809600
# In dir  s15_deep9_1435190400
# In dir  s15_deep9_1431302400
# In dir  s19_cmb_1559865600
# In dir  s14_boss_1411084800
# In dir  s19_cmb_1567382400
# In dir  s13_deep5_1380499200
# In dir  s15_deep9_1437264000
# In dir  s13_deep6_1385942400
# In dir  s19_cmb_1552089600
# In dir  s15_deep56_1445817600
# In dir  s15_deep8_1444003200
# In dir  s15_deep8_1448668800
# In dir  s13_deep1_1386460800
# In dir  s14_boss_1412899200
# In dir  s15_boss_1437782400
# In dir  s15_deep56_1438041600
# In dir  s16_day_14h_n_1476144000
# In dir  s13_deep5_1386979200
# In dir  s16_cmb_1464220800
# In dir  s18_cmb_1540684800
# In dir  s16_day_14h_n_1476662400
# In dir  s14_boss_1412380800
# In dir  s15_deep9_1432339200
# In dir  s17_cmb_1502323200
# In dir  s17_cmb_1512950400
# In dir  s17_cmb_1500508800
# In dir  s16_day_02h_s_1474588800
# In dir  s19_cmb_1565568000
# In dir  s14_boss_1418860800
# In dir  s16_day_14h_n_1464739200
# In dir  s16_day_02h_s_1478217600
# In dir  s16_day_14h_n_1476403200
# In dir  s16_day_02h_s_1475366400
# In dir  s19_cmb_1573084800
# In dir  s19_cmb_1562457600
# In dir  s17_cmb_1505174400
# In dir  s13_deep2_1384905600
# In dir  s16_day_02h_s_1464480000
# In dir  s15_deep56_1438560000
# In dir  s13_deep5_1386460800
# In dir  s16_day_02h_s_1476144000
# In dir  s15_boss_1445817600
# In dir  s16_day_02h_s_1480032000
# In dir  s18_cmb_1541980800
# In dir  s13_deep5_1386720000
# In dir  s15_deep8_1436227200
# In dir  s14_deep56_1412899200
# In dir  s16_day_02h_s_1477958400
# In dir  s16_cmb_1480291200
# In dir  s16_day_14h_n_1481846400
# In dir  s15_deep56_1447113600
# In dir  s19_cmb_1555977600
# In dir  s15_boss_1450742400
# In dir  s15_deep9_1437782400
# In dir  s15_deep56_1450483200
# In dir  s13_deep6_1382313600
# In dir  s13_deep5_1385942400
# In dir  s15_deep9_1433116800
# In dir  s16_cmb_1473292800
# In dir  s13_deep6_1380240000
# In dir  s15_deep9_1443484800
# In dir  s15_deep9_1433376000
# In dir  s16_day_02h_s_1481587200
# In dir  s13_deep2_1384646400
# In dir  s14_boss_1413417600
# In dir  s16_day_14h_n_1480032000
# In dir  s14_boss_1412640000
# In dir  s16_cmb_1479254400
# In dir  s16_cmb_1477699200
# In dir  s17_cmb_1500768000
# In dir  s16_cmb_1478476800
# In dir  s16_day_02h_s_1465257600
# In dir  s13_deep5_1385164800
# In dir  s19_cmb_1565049600
# In dir  s13_deep1_1378684800
# In dir  s17_cmb_1512172800
# In dir  s14_deep56_1415232000
# In dir  s15_deep56_1429747200
# In dir  s19_cmb_1569456000
# In dir  s16_day_02h_s_1480809600
# In dir  s15_boss_1431302400
# In dir  s15_deep56_1438300800
# In dir  s15_deep56_1433376000
# In dir  s14_boss_1415491200
# In dir  s17_cmb_1514505600
# In dir  s16_day_02h_s_1477180800
# In dir  s19_cmb_1574640000
# In dir  s13_deep2_1387238400
# In dir  s15_deep56_1444003200
# In dir  s15_deep56_1442448000
# In dir  s14_boss_1416787200
# In dir  s15_boss_1434931200
# In dir  s15_deep56_1446854400
# In dir  s19_cmb_1561939200
# In dir  s15_boss_1434153600
# In dir  s19_cmb_1552348800
# In dir  s15_deep56_1430524800
# In dir  s17_cmb_1504656000
# In dir  s15_deep8_1446595200
# In dir  s17_cmb_1494806400
# In dir  s19_cmb_1554681600
# In dir  s14_deep56_1414713600
# In dir  s15_deep56_1438819200
# In dir  s15_deep8_1433894400
# In dir  s16_day_02h_s_1480550400
# In dir  s15_deep56_1434931200
# In dir  s19_cmb_1568678400
# In dir  s14_boss_1419379200
# In dir  s13_deep5_1385683200
# In dir  s13_deep1_1385942400
# In dir  s15_boss_1433376000
# In dir  s15_deep8_1451520000
# In dir  s16_cmb_1473552000
# In dir  s17_cmb_1504137600
# In dir  s15_boss_1448409600
# In dir  s19_cmb_1563753600
# In dir  s18_cmb_1538092800
# In dir  s14_boss_1411344000
# In dir  s16_cmb_1482105600
# In dir  s14_deep56_1417046400
# In dir  s15_deep8_1438300800
# In dir  s13_deep2_1385424000
# In dir  s15_deep56_1437264000
# In dir  s15_boss_1447113600
# In dir  s15_deep8_1432339200
# In dir  s15_deep8_1449964800
# In dir  s19_cmb_1559606400
# In dir  s16_day_02h_s_1475625600
# In dir  s15_deep8_1431561600
# In dir  s15_boss_1449187200
# In dir  s18_cmb_1539129600
# In dir  s18_cmb_1525910400
# In dir  s16_cmb_1464739200
# In dir  s15_boss_1437264000
# In dir  s17_cmb_1514764800
# In dir  s18_cmb_1537574400
# In dir  s16_cmb_1463961600
# In dir  s18_cmb_1542499200
# In dir  s15_boss_1436227200
# In dir  s13_deep5_1381017600
# In dir  s17_cmb_1510617600
# In dir  s16_day_02h_s_1479772800
# In dir  s14_boss_1414454400
# no info file in  s14_boss_1414454400
# In dir  s15_boss_1438300800
# In dir  s15_boss_1442966400
# In dir  s16_cmb_1482364800
# In dir  s15_deep8_1443225600
# In dir  s15_boss_1442448000
# In dir  s16_day_02h_s_1476662400
# In dir  s16_cmb_1476144000
# In dir  s13_deep5_1384905600
# In dir  s15_deep56_1448668800
# In dir  s14_boss_1409788800
# In dir  s15_deep8_1448150400
# In dir  s19_cmb_1570233600
# In dir  s13_deep6_1382054400
# In dir  s15_boss_1448668800
# In dir  s19_cmb_1563494400
# In dir  s15_deep56_1448928000
# In dir  s19_cmb_1562716800
# In dir  s13_deep5_1379203200
# In dir  s15_deep8_1438041600
# In dir  s13_deep5_1386201600
# In dir  s18_cmb_1540166400
# In dir  s14_boss_1415232000
# In dir  s15_deep56_1437782400
# In dir  s15_boss_1430524800
# In dir  s15_deep8_1433376000
# In dir  s16_cmb_1477440000
# In dir  s17_cmb_1515283200
# In dir  s16_day_14h_n_1463961600
# In dir  s15_deep56_1447891200
# In dir  s18_cmb_1536537600
# In dir  s18_cmb_1537056000
# In dir  s15_boss_1444780800
# In dir  s16_cmb_1464480000
# In dir  s15_boss_1438560000
# In dir  s13_deep5_1383350400
# In dir  s18_cmb_1527206400
# In dir  s13_deep1_1382832000
# In dir  s15_boss_1438041600
# In dir  s19_cmb_1575158400
# In dir  s13_deep1_1381795200
# In dir  s14_deep56_1418860800
# In dir  s16_day_14h_n_1481068800
# In dir  s18_cmb_1539907200
# In dir  s16_day_02h_s_1478995200
# In dir  s17_cmb_1512691200
# In dir  s15_deep8_1441670400
# In dir  s15_boss_1451001600
# In dir  s15_boss_1448928000
# In dir  s15_deep8_1436745600
# In dir  s14_boss_1419897600
# In dir  s15_boss_1434672000
# In dir  s14_boss_1414195200
# no info file in  s14_boss_1414195200
# In dir  s13_deep6_1386201600
# In dir  s15_deep9_1438560000
# In dir  s14_boss_1418083200
# In dir  s16_cmb_1477958400
# In dir  s16_day_14h_n_1471219200
# In dir  s15_boss_1430784000
# In dir  s15_deep8_1442188800
# In dir  s16_day_14h_n_1478217600
# In dir  s15_deep56_1442966400
# In dir  s16_day_02h_s_1477440000
# In dir  s15_deep8_1450224000
# In dir  s13_deep5_1383091200
# In dir  s16_day_02h_s_1473292800
# In dir  s13_deep6_1382572800
# In dir  s13_deep5_1384646400
# In dir  s16_day_14h_n_1474329600
# In dir  s15_deep56_1433116800
# In dir  s17_cmb_1511395200
# In dir  s13_deep6_1381536000
# In dir  s16_day_02h_s_1476403200
# In dir  s14_deep56_1415491200
# In dir  s17_cmb_1502841600
# In dir  s16_day_02h_s_1472774400
# In dir  s16_day_02h_s_1476921600
# In dir  s15_deep56_1443484800
# In dir  s14_deep56_1417824000
# In dir  s14_deep56_1413936000
# In dir  s15_boss_1444003200
# In dir  s13_deep6_1386460800
# In dir  s14_boss_1418601600
# In dir  s15_boss_1447372800
# In dir  s16_day_02h_s_1474848000
# In dir  s17_cmb_1511136000
# In dir  s16_day_02h_s_1481068800
# In dir  s16_cmb_1471996800
# In dir  s14_deep56_1416787200
# In dir  s15_deep56_1444262400
# In dir  s16_day_02h_s_1474329600
# In dir  s15_deep56_1451260800
# In dir  s19_cmb_1562976000
# In dir  s14_boss_1414972800
# no info file in  s14_boss_1414972800
# In dir  s13_deep2_1386720000
# In dir  s19_cmb_1554163200
# In dir  s16_day_02h_s_1479513600
# In dir  s15_deep56_1452297600
# In dir  s14_deep56_1410307200
# In dir  s14_boss_1416009600
# In dir  s15_boss_1444521600
# In dir  s15_deep56_1444521600
# In dir  s15_boss_1439078400
# In dir  s14_boss_1411603200
# In dir  s19_cmb_1574121600
# In dir  s19_cmb_1571011200
# In dir  s14_deep56_1414195200
# In dir  s16_day_14h_n_1479513600
# In dir  s14_deep56_1419379200
# In dir  s16_day_14h_n_1475625600
# In dir  s17_cmb_1514246400
# In dir  s15_deep8_1436486400
# In dir  s15_deep56_1437523200
# In dir  s15_deep56_1442707200
# In dir  s13_deep6_1383609600
# In dir  s15_boss_1431043200
# In dir  s14_boss_1416268800
# In dir  s13_deep6_1381795200
# In dir  s15_deep8_1442707200
# In dir  s13_deep1_1383091200
# In dir  s13_deep2_1385164800
# In dir  s15_deep8_1451001600
# In dir  s15_deep56_1433894400
# In dir  s15_deep9_1434412800
# In dir  s15_deep9_1438819200
# In dir  s15_deep8_1431302400
# In dir  s13_deep1_1385424000
# In dir  s14_deep56_1411344000
# In dir  s14_deep56_1418601600
# In dir  s16_cmb_1465257600
# In dir  s19_cmb_1573862400
# In dir  s18_cmb_1540425600
# In dir  s16_cmb_1474329600
# In dir  s15_deep56_1449187200
# In dir  s14_deep56_1411603200
# In dir  s15_deep8_1449446400
# In dir  s15_boss_1443225600
# In dir  s16_cmb_1476662400
# In dir  s13_deep1_1380499200
# In dir  s15_boss_1436745600
# In dir  s15_boss_1442707200
# In dir  s15_boss_1452038400
# In dir  s17_cmb_1513209600
# In dir  s15_deep56_1429488000
# In dir  s18_cmb_1536278400
# In dir  s18_cmb_1527465600
# In dir  s14_deep56_1417564800
# In dir  s15_deep56_1449964800
# In dir  s15_boss_1429488000
# In dir  s13_deep2_1383091200
# In dir  s15_deep8_1451260800
# In dir  s14_boss_1419120000
# In dir  s16_day_14h_n_1474588800
# In dir  s15_deep56_1432080000
# In dir  s13_deep1_1385683200
# In dir  s16_day_02h_s_1472515200
# In dir  s14_boss_1409529600
# In dir  s14_deep56_1411862400
# In dir  s16_day_14h_n_1478476800
# In dir  s15_boss_1442188800
# In dir  s15_boss_1449705600
# In dir  s13_deep6_1383350400
# In dir  s18_cmb_1541462400
# In dir  s18_cmb_1543017600
# In dir  s16_day_02h_s_1475884800
# In dir  s18_cmb_1540944000
# In dir  s15_deep56_1449446400
# In dir  s13_deep6_1386720000
# In dir  s15_deep9_1442448000
# In dir  s15_deep56_1447372800
# In dir  s15_deep8_1430524800
# In dir  s16_day_14h_n_1481587200
# In dir  s15_boss_1435968000
# In dir  s15_deep56_1448150400
# In dir  s16_day_14h_n_1475107200
# In dir  s16_day_14h_n_1478995200
# In dir  s16_day_02h_s_1474070400
# In dir  s15_deep56_1431561600
# In dir  s14_deep56_1414972800
# In dir  s13_deep6_1380758400
# In dir  s19_cmb_1569974400
# In dir  s15_boss_1450224000
# In dir  s15_deep8_1448928000
# In dir  s15_deep56_1435190400
# In dir  s18_cmb_1539388800
# In dir  s14_boss_1413158400
# In dir  s14_deep56_1413158400
# In dir  s15_deep8_1447113600
# In dir  s17_cmb_1515024000
# In dir  s16_cmb_1473811200
# In dir  s17_cmb_1509321600
# In dir  s15_deep8_1431043200
# In dir  s15_deep56_1439337600
# In dir  s16_cmb_1472256000
# In dir  s16_day_02h_s_1464998400
# In dir  s15_boss_1447891200
# In dir  s15_deep9_1435968000
# In dir  s17_cmb_1506470400
# In dir  s14_deep56_1409788800
# In dir  s15_boss_1433116800
# In dir  s18_cmb_1543795200
# In dir  s16_day_02h_s_1463961600
# In dir  s15_deep9_1443225600
# In dir  s18_cmb_1527724800
# In dir  s13_deep5_1382832000
# In dir  s18_cmb_1543536000
# In dir  s17_cmb_1506729600
# In dir  s15_deep56_1443744000
# In dir  s15_deep8_1449187200
# In dir  s13_deep1_1379203200
# In dir  s14_deep56_1419120000
# In dir  s16_day_14h_n_1474070400
# In dir  s15_boss_1447632000
# In dir  s16_day_14h_n_1480550400
# In dir  s13_deep2_1384128000
# In dir  s15_deep8_1446336000
# In dir  s19_cmb_1555200000
# In dir  s15_boss_1433635200
# In dir  s17_cmb_1516060800
# In dir  s16_day_14h_n_1464220800
# In dir  s15_deep9_1433894400
# In dir  s16_cmb_1475884800
# In dir  s18_cmb_1538611200
# In dir  s19_cmb_1554940800
# In dir  s15_deep56_1434672000
# In dir  s17_cmb_1495324800
# In dir  s19_cmb_1567123200
# In dir  s19_cmb_1557014400
# In dir  s15_deep8_1435708800
# In dir  s17_cmb_1513987200
# In dir  s14_deep56_1410048000
# In dir  s16_day_14h_n_1477958400
# In dir  s19_cmb_1568419200
# In dir  s15_boss_1432339200
# In dir  s17_cmb_1509062400
# In dir  s19_cmb_1565827200
# In dir  s16_day_14h_n_1475366400
# In dir  s17_cmb_1501545600
# In dir  s19_cmb_1566086400
# In dir  s15_deep56_1451779200
# In dir  s16_day_02h_s_1475107200
# In dir  s16_cmb_1472515200
# In dir  s14_boss_1417046400
# In dir  s15_deep56_1435968000
# In dir  s19_cmb_1567641600
# In dir  s16_day_02h_s_1473033600
# In dir  s13_deep5_1380758400
# In dir  s19_cmb_1560643200
# In dir  s13_deep6_1382832000
# In dir  s17_cmb_1510876800
# In dir  s14_deep56_1416268800
# In dir  s18_cmb_1541203200
# In dir  s15_boss_1439596800
# In dir  s18_cmb_1528502400
# In dir  s16_day_02h_s_1473552000
# In dir  s13_deep2_1384387200
# In dir  s15_deep56_1445558400
# In dir  s16_cmb_1471219200
# In dir  s16_day_14h_n_1477180800
# In dir  s15_deep56_1446076800
# In dir  s13_deep2_1385942400
# In dir  s16_day_02h_s_1471996800
# In dir  s13_deep1_1383350400
# In dir  s13_deep5_1378684800
# In dir  s14_deep56_1417305600
# In dir  s17_cmb_1515542400
# In dir  s13_deep6_1384387200
# In dir  s14_boss_1410048000
# In dir  s15_deep9_1441929600
# In dir  s17_cmb_1512432000
# In dir  s16_day_02h_s_1471737600
# In dir  s13_deep1_1380758400

# %%
europa.save_stack('/scratch/r/rbond/jorlo/actxminorplanets/asteroids/pks/')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-163-595713c09290> in <module>
# ----> 1 europa.save_stack('/scratch/r/rbond/jorlo/actxminorplanets/asteroids/pks')
#
# AttributeError: 'minorplanet' object has no attribute 'save_stack'

# %%
obs = 'W99' #San Pedro

#table = QueryHorizons(time_start=58429.52446208872-10000, time_end=58429.52446208872+10000, observer_location='W99', step = '1d').queryObjects(['Ceres'])
table = QueryHorizons(time_start='2010-01-01T00:00:00', time_end='2020-01-01T00:00:00', observer_location='W99', step = '1d').queryObjects(['Vesta'])

# %%
orbits = OrbitInterpolator(table)

# %%
t_start = Time('2013-01-01T00:00:00', format='isot', scale='utc')
t_start = t_start.mjd

t_en = Time('2020-01-01T00:00:00', format='isot', scale='utc')
t_en = t_en.mjd
mjds = np.linspace(t_start, t_en, 1000)

ras, decs, delts = orbits.get_radec_dist(table['targetname'][0], mjds)

plt.plot(ras, decs)
plt.show()
# Out:
# dict_keys(['4 Vesta (A807 FA)'])

# %%
flux_stack, fstack, kstack, flux_scale = tnoStacker(orbits,table['targetname'][0])
# Out:
# stacking on  4 Vesta (A807 FA)
# In dir  s18_cmb_1536796800
# dict_keys(['4 Vesta (A807 FA)'])
# 2267.3426964798473 16288.78558264324
# 2267.3426964798473 16288.78558264324
# In dir  s18_cmb_1542240000
# dict_keys(['4 Vesta (A807 FA)'])
# 2298.198358278296 14694.860761429662
# 2298.198358278296 14694.860761429662
# In dir  s15_deep8_1437523200
# dict_keys(['4 Vesta (A807 FA)'])
# 2960.3056453991776 244.5475363413443
# 2960.3056453991776 244.5475363413443
# In dir  s15_deep9_1435449600
# dict_keys(['4 Vesta (A807 FA)'])
# 2791.4024182636276 6490.136319598942
# 2791.4024182636276 6490.136319598942
# In dir  s16_cmb_1476921600
# dict_keys(['4 Vesta (A807 FA)'])
# 4935.346886075653 3476.7257945749207
# 4935.346886075653 3476.7257945749207
# In dir  s15_deep9_1442707200
# dict_keys(['4 Vesta (A807 FA)'])
# 2518.4510361455104 6326.878386803148
# 2518.4510361455104 6326.878386803148
# In dir  s15_deep56_1451001600
# dict_keys(['4 Vesta (A807 FA)'])
# 352.238268488396 2868.1819732657314
# 352.238268488396 2868.1819732657314
# In dir  s19_cmb_1556755200
# dict_keys(['4 Vesta (A807 FA)'])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in _try_while_unread_hdus(self, func, *args, **kwargs)
#    1107             try:
# -> 1108                 return func(*args, **kwargs)
#    1109             except Exception:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/hdu/base.py in _readfrom_internal(cls, data, header, checksum, ignore_missing_end, **kwargs)
#     405                     # that are needed to build the HDU object.
# --> 406                     header_str, header = _BasicHeader.fromfile(data)
#     407                 except Exception:
#
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/header.py in fromfile(cls, fileobj)
#    2079         try:
# -> 2080             header_str, cards = parse_header(fileobj)
#    2081             _check_padding(header_str, BLOCK_SIZE, False)
#
# astropy/io/fits/_utils.pyx in astropy.io.fits._utils.parse_header()
#
# Exception:
#
# During handling of the above exception, another exception occurred:
#
# StopIteration                             Traceback (most recent call last)
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/header.py in _from_blocks(cls, block_iter, is_binary, sep, endcard, padding)
#     559         try:
# --> 560             block = next(blocks)
#     561         except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-134-20152cc7115b> in <module>
# ----> 1 flux_stack, fstack, kstack, flux_scale = tnoStacker(orbits,table['targetname'][0])
#
# <ipython-input-129-55b63e67af4c> in tnoStacker(oribits, obj)
#     203         #Get wcs info from the kmap for this 3day coadd: for sigurd's maps the kmap and
#     204         #frhs map wcs info will be the same
# --> 205         hdu = fits.open(path + dirname + '/kmap.fits')
#     206         w = wcs.WCS(hdu[0].header)
#     207
#
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     162
#     163     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
# --> 164                             lazy_load_hdus, **kwargs)
#     165
#     166
#
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     400         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     401                              save_backup=save_backup, cache=cache,
# --> 402                              lazy_load_hdus=lazy_load_hdus, **kwargs)
#     403
#     404     @classmethod
#
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in _readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, **kwargs)
#    1074
#    1075         # Make sure at least the PRIMARY HDU can be read
# -> 1076         read_one = hdulist._read_next_hdu()
#    1077
#    1078         # If we're trying to read only and no header units were found,
#
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in _read_next_hdu(self)
#    1176                     # Check for an extension HDU and update the EXTEND
#    1177                     # keyword of the primary HDU accordingly
# -> 1178                     self.update_extend()
#    1179
#    1180                 hdu._new = False
#
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in update_extend(self)
#     873             if not hdr['EXTEND'] and get_first_ext() is not None:
#     874                 hdr['EXTEND'] = True
# --> 875         elif get_first_ext() is not None:
#     876             if hdr['NAXIS'] == 0:
#     877                 hdr.set('EXTEND', True, after='NAXIS')
#
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in get_first_ext()
#     866         def get_first_ext():
#     867             try:
# --> 868                 return self[1]
#     869             except IndexError:
#     870                 return None
#
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in __getitem__(self, key)
#     309         try:
#     310             return self._try_while_unread_hdus(super().__getitem__,
# --> 311                                                self._positive_index_of(key))
#     312         except IndexError as e:
#     313             # Raise a more helpful IndexError if the file was not fully read.
#
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in _try_while_unread_hdus(self, func, *args, **kwargs)
#    1108                 return func(*args, **kwargs)
#    1109             except Exception:
# -> 1110                 if self._read_next_hdu():
#    1111                     continue
#    1112                 else:
#
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in _read_next_hdu(self)
#    1149                                 fileobj.seek(offset, os.SEEK_SET)
#    1150
# -> 1151                         hdu = _BaseHDU.readfrom(fileobj, **kwargs)
#    1152                     except EOFError:
#    1153                         self._read_all = True
#
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/hdu/base.py in readfrom(cls, fileobj, checksum, ignore_missing_end, **kwargs)
#     325         hdu = cls._readfrom_internal(fileobj, checksum=checksum,
#     326                                      ignore_missing_end=ignore_missing_end,
# --> 327                                      **kwargs)
#     328
#     329         # If the checksum had to be checked the data may have already been read
#
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/hdu/base.py in _readfrom_internal(cls, data, header, checksum, ignore_missing_end, **kwargs)
#     412                     data.seek(header_offset)
#     413                     header = Header.fromfile(data,
# --> 414                                              endcard=not ignore_missing_end)
#     415             hdu_fileobj = data
#     416             data_offset = data.tell()  # *after* reading the header
#
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/header.py in fromfile(cls, fileobj, sep, endcard, padding)
#     516
#     517             return cls._from_blocks(block_iter, is_binary, sep, endcard,
# --> 518                                     padding)[1]
#     519         finally:
#     520             if close_file:
#
# ~/actmadcows/lib/python3.6/site-packages/astropy/io/fits/header.py in _from_blocks(cls, block_iter, is_binary, sep, endcard, padding)
#     558         # Read the first header block.
#     559         try:
# --> 560             block = next(blocks)
#     561         except StopIteration:
#     562             raise EOFError()
#
# KeyboardInterrupt:

# %%
plt.imshow(flux_stack)
plt.savefig('/scratch/r/rbond/jorlo/actxminorplanets/asteroids/plots/{}_stamp.pdf'.format(str(table['targetname'][0]).replace(' ', '_').replace('(','').replace(')','')))
plt.show()

aster_dict = {'flux_stack':flux_stack, 'fstack':fstack, 'kstack':kstack, 'flux_scale':flux_scale}
with open('/scratch/r/rbond/jorlo/actxminorplanets/asteroids/pks/{}_stamp.pk'.format(str(table['targetname'][0]).replace(' ', '_').replace('(','').replace(')','')), 'wb') as f:
    pk.dump(aster_dict, f)

# %%
with open('/scratch/r/rbond/jorlo/actxminorplanets/asteroids/pks/{}_stamp.pk'.format(str(table['targetname'][0]).replace(' ', '_').replace('(','').replace(')','')), 'rb') as f:
    aster_dict = pk.load(f)
    kstack = aster_dict['kstack']
    fstack = aster_dict['fstack']
    
    flux_stack = fstack/kstack    
    plt.imshow(flux_stack)
    plt.show()

# %%
path = '/home/r/rbond/sigurdkn/scratch/actpol/planet9/20200801/maps/combined/'


table = QueryHorizons(time_start='2010-01-01T00:00:00', time_end='2020-01-01T00:00:00', observer_location='W99', step = '1d').queryObjects([502])

orbits =  OrbitInterpolator(table)

for  dirname in os.listdir(path=path):
    try:
        with h5py.File(path + dirname +"/info.hdf", "r") as hfile:
            #Find the (rough) mjd center of the map
            mjd_cent = hfile["mjd"][()]
            
        print(hfile.header())

    except:
        print('no info file in ', dirname)
        continue
    ra, dec, delta = orbits.get_radec_dist(table['targetname'][0], mjd_cent)
    print(ra, dec, delta)
# Out:
# 0
# no info file in  s18_cmb_1536796800
# no info file in  s18_cmb_1542240000
# no info file in  s15_deep8_1437523200
# no info file in  s15_deep9_1435449600
# no info file in  s16_cmb_1476921600
# no info file in  s15_deep9_1442707200
# no info file in  s15_deep56_1451001600
# no info file in  s19_cmb_1556755200
# no info file in  s13_deep2_1383350400
# no info file in  s15_deep8_1447372800
# no info file in  s13_deep5_1387497600
# no info file in  s15_deep9_1439596800
# no info file in  s15_deep9_1438300800
# no info file in  s15_deep8_1439337600
# no info file in  s19_cmb_1564272000
# no info file in  s13_deep5_1381795200
# no info file in  s15_boss_1438819200
# no info file in  s15_deep9_1442966400
# no info file in  s13_deep6_1380499200
# no info file in  s15_deep8_1432857600
# no info file in  s13_deep1_1378944000
# no info file in  s16_cmb_1480032000
# no info file in  s13_deep1_1383609600
# no info file in  s13_deep6_1387497600
# no info file in  s19_cmb_1572566400
# no info file in  s16_cmb_1471737600
# no info file in  s15_deep56_1446595200
# no info file in  s16_cmb_1478995200
# no info file in  s15_deep8_1444521600
# no info file in  s15_deep9_1433635200
# no info file in  s18_cmb_1525651200
# no info file in  s16_cmb_1478217600
# no info file in  s18_cmb_1544054400
# no info file in  s19_cmb_1561420800
# no info file in  s13_deep6_1384646400
# no info file in  s13_deep1_1384387200
# no info file in  s16_cmb_1474848000
# no info file in  s14_deep56_1418342400
# no info file in  s15_deep8_1433635200
# no info file in  s18_cmb_1541721600
# no info file in  s15_boss_1434412800
# no info file in  s19_cmb_1571529600
# no info file in  s16_cmb_1479772800
# no info file in  s14_boss_1417824000
# no info file in  s14_deep56_1412380800
# no info file in  s17_cmb_1501286400
# no info file in  s13_deep5_1385424000
# no info file in  s16_day_14h_n_1477699200
# no info file in  s15_deep8_1438560000
# no info file in  s16_cmb_1477180800
# no info file in  s13_deep1_1382572800
# no info file in  s19_cmb_1565308800
# no info file in  s15_deep9_1434153600
# no info file in  s14_deep56_1416009600
# no info file in  s15_boss_1435449600
# no info file in  s15_boss_1446854400
# no info file in  s15_boss_1448150400
# no info file in  s15_deep8_1445817600
# no info file in  s13_deep6_1383091200
# no info file in  s19_cmb_1566864000
# no info file in  s19_cmb_1568937600
# no info file in  s15_deep56_1442188800
# no info file in  s15_deep8_1441929600
# no info file in  s15_deep56_1436227200
# no info file in  s19_cmb_1572825600
# no info file in  s16_day_14h_n_1475884800
# no info file in  s13_deep5_1382313600
# no info file in  s13_deep5_1381276800
# no info file in  s15_boss_1429747200
# no info file in  s13_deep6_1381017600
# no info file in  s19_cmb_1569196800
# no info file in  s13_deep2_1386460800
# no info file in  s15_boss_1443744000
# no info file in  s15_deep56_1435449600
# no info file in  s19_cmb_1566345600
# no info file in  s16_day_14h_n_1474848000
# no info file in  s19_cmb_1575936000
# no info file in  s14_boss_1413936000
# no info file in  s15_deep9_1434931200
# no info file in  s15_deep8_1446854400
# no info file in  s14_boss_1417564800
# no info file in  s17_cmb_1507248000
# no info file in  s16_day_02h_s_1472256000
# no info file in  s15_deep8_1443484800
# no info file in  s19_cmb_1576454400
# no info file in  s13_deep2_1381795200
# no info file in  s19_cmb_1564790400
# no info file in  s13_deep6_1379462400
# no info file in  s16_day_02h_s_1473811200
# no info file in  s19_cmb_1573344000
# no info file in  s14_boss_1416528000
# no info file in  s15_deep8_1439078400
# no info file in  s17_cmb_1504915200
# no info file in  s15_deep8_1437782400
# no info file in  s16_day_02h_s_1465516800
# no info file in  s15_deep8_1434412800
# no info file in  s15_deep56_1431820800
# no info file in  s14_deep56_1419897600
# no info file in  s15_deep56_1446336000
# no info file in  s14_boss_1414713600
# no info file in  s14_boss_1408752000
# no info file in  s15_deep56_1436745600
# no info file in  s17_cmb_1509840000
# no info file in  s15_deep56_1434153600
# no info file in  s16_day_02h_s_1464739200
# no info file in  s14_boss_1415750400
# no info file in  s17_cmb_1505692800
# no info file in  s16_day_14h_n_1481328000
# no info file in  s18_cmb_1527984000
# no info file in  s16_cmb_1481068800
# no info file in  s13_deep6_1378684800
# no info file in  s19_cmb_1561161600
# no info file in  s16_day_14h_n_1473811200
# no info file in  s15_deep9_1432857600
# no info file in  s13_deep1_1379980800
# no info file in  s15_deep8_1435449600
# no info file in  s13_deep5_1380240000
# no info file in  s16_day_14h_n_1464998400
# no info file in  s19_cmb_1575676800
# no info file in  s13_deep5_1387238400
# no info file in  s15_deep8_1443744000
# no info file in  s15_deep8_1442448000
# no info file in  s15_boss_1446336000
# no info file in  s13_deep5_1379462400
# no info file in  s15_deep56_1450224000
# no info file in  s19_cmb_1564012800
# no info file in  s15_deep8_1432080000
# no info file in  s16_day_14h_n_1477440000
# no info file in  s19_cmb_1551571200
# no info file in  s19_cmb_1570752000
# no info file in  s13_deep1_1383868800
# no info file in  s15_deep56_1451520000
# no info file in  s15_boss_1451520000
# no info file in  s15_boss_1431820800
# no info file in  s17_cmb_1516320000
# no info file in  s15_boss_1437523200
# no info file in  s17_cmb_1511654400
# no info file in  s15_boss_1432857600
# no info file in  s17_cmb_1501027200
# no info file in  s15_deep56_1432339200
# no info file in  s14_deep56_1413417600
# no info file in  s16_cmb_1474588800
# no info file in  s15_boss_1430265600
# no info file in  s19_cmb_1552867200
# no info file in  s13_deep1_1379721600
# no info file in  s15_deep56_1441670400
# no info file in  s13_deep2_1378684800
# no info file in  s15_deep56_1434412800
# no info file in  s13_deep6_1383868800
# no info file in  s16_day_02h_s_1478476800
# no info file in  s15_boss_1435190400
# no info file in  s14_deep56_1408752000
# no info file in  s16_cmb_1481328000
# no info file in  s15_boss_1431561600
# no info file in  s15_boss_1449964800
# no info file in  s13_deep5_1378944000
# no info file in  s19_cmb_1560124800
# no info file in  s15_boss_1451779200
# no info file in  s15_deep56_1439596800
# no info file in  s13_deep2_1382054400
# no info file in  s15_deep56_1435708800
# no info file in  s16_cmb_1480550400
# no info file in  s15_deep9_1436227200
# no info file in  s15_boss_1451260800
# no info file in  s16_cmb_1478736000
# no info file in  s15_boss_1439337600
# no info file in  s13_deep5_1383609600
# no info file in  s15_deep8_1450742400
# no info file in  s15_deep9_1439078400
# no info file in  s18_cmb_1539648000
# no info file in  s14_deep56_1414454400
# no info file in  s15_boss_1445558400
# no info file in  s19_cmb_1563235200
# no info file in  s13_deep2_1382832000
# no info file in  s14_boss_1410307200
# no info file in  s13_deep6_1384128000
# no info file in  s15_deep8_1442966400
# no info file in  s14_deep56_1416528000
# no info file in  s15_deep56_1433635200
# no info file in  s19_cmb_1572048000
# no info file in  s14_boss_1413676800
# no info file in  s13_deep5_1384128000
# no info file in  s15_boss_1446076800
# no info file in  s17_cmb_1505952000
# no info file in  s16_day_14h_n_1479772800
# no info file in  s15_deep9_1437523200
# no info file in  s14_deep56_1419638400
# no info file in  s16_day_02h_s_1477699200
# no info file in  s19_cmb_1570492800
# no info file in  s17_cmb_1506988800
# no info file in  s18_cmb_1537833600
# no info file in  s19_cmb_1551830400
# no info file in  s13_deep5_1384387200
# no info file in  s14_boss_1411862400
# no info file in  s13_deep1_1384646400
# no info file in  s15_deep9_1439337600
# no info file in  s13_deep6_1384905600
# no info file in  s13_deep1_1386720000
# no info file in  s15_deep56_1447632000
# no info file in  s15_deep9_1442188800
# no info file in  s16_cmb_1476403200
# no info file in  s15_boss_1441670400
# no info file in  s19_cmb_1575417600
# no info file in  s19_cmb_1572307200
# no info file in  s15_deep9_1431561600
# no info file in  s16_day_14h_n_1482364800
# no info file in  s17_cmb_1504396800
# no info file in  s16_cmb_1465516800
# no info file in  s16_day_14h_n_1480291200
# no info file in  s15_deep56_1443225600
# no info file in  s13_deep5_1379721600
# no info file in  s16_day_02h_s_1471219200
# no info file in  s17_cmb_1499731200
# no info file in  s19_cmb_1556236800
# no info file in  s17_cmb_1513468800
# no info file in  s13_deep2_1383868800
# no info file in  s19_cmb_1566604800
# no info file in  s15_deep9_1435708800
# no info file in  s19_cmb_1554422400
# no info file in  s13_deep2_1383609600
# no info file in  s16_cmb_1474070400
# no info file in  s15_deep8_1452038400
# no info file in  s13_deep1_1381017600
# no info file in  s17_cmb_1499990400
# no info file in  s13_deep6_1379721600
# no info file in  s14_deep56_1412640000
# no info file in  s18_cmb_1538352000
# no info file in  s15_deep56_1436486400
# no info file in  s15_deep56_1430784000
# no info file in  s15_deep8_1434153600
# no info file in  s13_deep5_1381536000
# no info file in  s19_cmb_1561680000
# no info file in  s18_cmb_1538870400
# no info file in  s15_deep8_1438819200
# no info file in  s13_deep1_1384905600
# no info file in  s15_deep8_1434931200
# no info file in  s15_boss_1443484800
# no info file in  s15_deep9_1438041600
# no info file in  s19_cmb_1564531200
# no info file in  s16_cmb_1473033600
# no info file in  s14_boss_1418342400
# no info file in  s14_boss_1417305600
# no info file in  s16_day_14h_n_1480809600
# no info file in  s15_boss_1433894400
# no info file in  s15_deep56_1449705600
# no info file in  s17_cmb_1500249600
# no info file in  s19_cmb_1553126400
# no info file in  s18_cmb_1544313600
# no info file in  s13_deep1_1387497600
# no info file in  s13_deep1_1382054400
# no info file in  s13_deep5_1383868800
# no info file in  s15_deep56_1441929600
# no info file in  s15_boss_1446595200
# no info file in  s14_deep56_1415750400
# no info file in  s17_cmb_1506211200
# no info file in  s13_deep6_1386979200
# no info file in  s16_day_02h_s_1471478400
# no info file in  s15_deep56_1431302400
# no info file in  s16_cmb_1481846400
# no info file in  s15_deep56_1439078400
# no info file in  s19_cmb_1573603200
# no info file in  s13_deep5_1379980800
# no info file in  s13_deep1_1381276800
# no info file in  s19_cmb_1552608000
# no info file in  s15_deep56_1450742400
# no info file in  s18_cmb_1543276800
# no info file in  s14_deep56_1409011200
# no info file in  s19_cmb_1551312000
# no info file in  s18_cmb_1537315200
# no info file in  s17_cmb_1510099200
# no info file in  s14_deep56_1418083200
# no info file in  s15_boss_1441929600
# no info file in  s15_deep8_1444780800
# no info file in  s16_cmb_1479513600
# no info file in  s13_deep6_1385164800
# no info file in  s13_deep1_1379462400
# no info file in  s13_deep2_1386979200
# no info file in  s15_boss_1432080000
# no info file in  s15_deep8_1430784000
# no info file in  s19_cmb_1553644800
# no info file in  s16_cmb_1475625600
# no info file in  s16_cmb_1475366400
# no info file in  s15_boss_1436486400
# no info file in  s13_deep6_1378944000
# no info file in  s19_cmb_1569715200
# no info file in  s16_day_14h_n_1478736000
# no info file in  s15_deep8_1437264000
# no info file in  s15_deep56_1432857600
# no info file in  s16_cmb_1472774400
# no info file in  s13_deep1_1386201600
# no info file in  s15_deep8_1433116800
# no info file in  s13_deep1_1386979200
# no info file in  s13_deep6_1387238400
# no info file in  s16_cmb_1481587200
# no info file in  s16_day_14h_n_1482105600
# no info file in  s15_deep8_1439596800
# no info file in  s15_deep8_1435968000
# no info file in  s15_deep56_1444780800
# no info file in  s17_cmb_1511913600
# no info file in  s19_cmb_1556496000
# no info file in  s14_deep56_1412121600
# no info file in  s13_deep5_1382572800
# no info file in  s15_boss_1452297600
# no info file in  s15_deep9_1434672000
# no info file in  s16_day_02h_s_1480291200
# no info file in  s14_boss_1419638400
# no info file in  s19_cmb_1571788800
# no info file in  s16_day_02h_s_1481846400
# no info file in  s15_deep8_1451779200
# no info file in  s17_cmb_1503100800
# no info file in  s16_day_14h_n_1479254400
# no info file in  s19_cmb_1574380800
# no info file in  s16_day_14h_n_1476921600
# no info file in  s19_cmb_1553385600
# no info file in  s15_deep8_1434672000
# no info file in  s13_deep1_1387238400
# no info file in  s15_deep8_1431820800
# no info file in  s15_deep9_1441670400
# no info file in  s15_deep56_1431043200
# no info file in  s13_deep1_1381536000
# no info file in  s19_cmb_1560384000
# no info file in  s15_deep56_1452038400
# no info file in  s13_deep2_1382572800
# no info file in  s15_deep56_1430265600
# no info file in  s15_deep9_1432080000
# no info file in  s15_boss_1449446400
# no info file in  s13_deep6_1379980800
# no info file in  s15_deep8_1449705600
# no info file in  s19_cmb_1571270400
# no info file in  s17_cmb_1513728000
# no info file in  s14_deep56_1409529600
# no info file in  s13_deep5_1382054400
# no info file in  s18_cmb_1528243200
# no info file in  s13_deep1_1382313600
# no info file in  s17_cmb_1505433600
# no info file in  s13_deep2_1382313600
# no info file in  s15_deep8_1446076800
# no info file in  s16_day_14h_n_1465257600
# no info file in  s16_day_02h_s_1478736000
# no info file in  s15_deep56_1448409600
# no info file in  s19_cmb_1574899200
# no info file in  s15_deep9_1431820800
# no info file in  s15_deep8_1435190400
# no info file in  s19_cmb_1555459200
# no info file in  s19_cmb_1562198400
# no info file in  s13_deep6_1385683200
# no info file in  s13_deep6_1381276800
# no info file in  s16_day_02h_s_1479254400
# no info file in  s13_deep6_1379203200
# no info file in  s17_cmb_1495065600
# no info file in  s14_deep56_1413676800
# no info file in  s19_cmb_1555718400
# no info file in  s19_cmb_1576195200
# no info file in  s14_boss_1409011200
# no info file in  s15_deep9_1436486400
# no info file in  s13_deep1_1385164800
# no info file in  s16_cmb_1475107200
# no info file in  s16_day_02h_s_1481328000
# no info file in  s19_cmb_1560902400
# no info file in  s15_deep8_1447891200
# no info file in  s17_cmb_1509580800
# no info file in  s17_cmb_1510358400
# no info file in  s16_day_02h_s_1464220800
# no info file in  s13_deep2_1381536000
# no info file in  s13_deep1_1384128000
# no info file in  s17_cmb_1507507200
# no info file in  s16_cmb_1464998400
# no info file in  s13_deep2_1385683200
# no info file in  s18_cmb_1542758400
# no info file in  s13_deep6_1385424000
# no info file in  s17_cmb_1501804800
# no info file in  s16_cmb_1471478400
# no info file in  s16_cmb_1480809600
# no info file in  s15_deep9_1435190400
# no info file in  s15_deep9_1431302400
# no info file in  s19_cmb_1559865600
# no info file in  s14_boss_1411084800
# no info file in  s19_cmb_1567382400
# no info file in  s13_deep5_1380499200
# no info file in  s15_deep9_1437264000
# no info file in  s13_deep6_1385942400
# no info file in  s19_cmb_1552089600
# no info file in  s15_deep56_1445817600
# no info file in  s15_deep8_1444003200
# no info file in  s15_deep8_1448668800
# no info file in  s13_deep1_1386460800
# no info file in  s14_boss_1412899200
# no info file in  s15_boss_1437782400
# no info file in  s15_deep56_1438041600
# no info file in  s16_day_14h_n_1476144000
# no info file in  s13_deep5_1386979200
# no info file in  s16_cmb_1464220800
# no info file in  s18_cmb_1540684800
# no info file in  s16_day_14h_n_1476662400
# no info file in  s14_boss_1412380800
# no info file in  s15_deep9_1432339200
# no info file in  s17_cmb_1502323200
# no info file in  s17_cmb_1512950400
# no info file in  s17_cmb_1500508800
# no info file in  s16_day_02h_s_1474588800
# no info file in  s19_cmb_1565568000
# no info file in  s14_boss_1418860800
# no info file in  s16_day_14h_n_1464739200
# no info file in  s16_day_02h_s_1478217600
# no info file in  s16_day_14h_n_1476403200
# no info file in  s16_day_02h_s_1475366400
# no info file in  s19_cmb_1573084800
# no info file in  s19_cmb_1562457600
# no info file in  s17_cmb_1505174400
# no info file in  s13_deep2_1384905600
# no info file in  s16_day_02h_s_1464480000
# no info file in  s15_deep56_1438560000
# no info file in  s13_deep5_1386460800
# no info file in  s16_day_02h_s_1476144000
# no info file in  s15_boss_1445817600
# no info file in  s16_day_02h_s_1480032000
# no info file in  s18_cmb_1541980800
# no info file in  s13_deep5_1386720000
# no info file in  s15_deep8_1436227200
# no info file in  s14_deep56_1412899200
# no info file in  s16_day_02h_s_1477958400
# no info file in  s16_cmb_1480291200
# no info file in  s16_day_14h_n_1481846400
# no info file in  s15_deep56_1447113600
# no info file in  s19_cmb_1555977600
# no info file in  s15_boss_1450742400
# no info file in  s15_deep9_1437782400
# no info file in  s15_deep56_1450483200
# no info file in  s13_deep6_1382313600
# no info file in  s13_deep5_1385942400
# no info file in  s15_deep9_1433116800
# no info file in  s16_cmb_1473292800
# no info file in  s13_deep6_1380240000
# no info file in  s15_deep9_1443484800
# no info file in  s15_deep9_1433376000
# no info file in  s16_day_02h_s_1481587200
# no info file in  s13_deep2_1384646400
# no info file in  s14_boss_1413417600
# no info file in  s16_day_14h_n_1480032000
# no info file in  s14_boss_1412640000
# no info file in  s16_cmb_1479254400
# no info file in  s16_cmb_1477699200
# no info file in  s17_cmb_1500768000
# no info file in  s16_cmb_1478476800
# no info file in  s16_day_02h_s_1465257600
# no info file in  s13_deep5_1385164800
# no info file in  s19_cmb_1565049600
# no info file in  s13_deep1_1378684800
# no info file in  s17_cmb_1512172800
# no info file in  s14_deep56_1415232000
# no info file in  s15_deep56_1429747200
# no info file in  s19_cmb_1569456000
# no info file in  s16_day_02h_s_1480809600
# no info file in  s15_boss_1431302400
# no info file in  s15_deep56_1438300800
# no info file in  s15_deep56_1433376000
# no info file in  s14_boss_1415491200
# no info file in  s17_cmb_1514505600
# no info file in  s16_day_02h_s_1477180800
# no info file in  s19_cmb_1574640000
# no info file in  s13_deep2_1387238400
# no info file in  s15_deep56_1444003200
# no info file in  s15_deep56_1442448000
# no info file in  s14_boss_1416787200
# no info file in  s15_boss_1434931200
# no info file in  s15_deep56_1446854400
# no info file in  s19_cmb_1561939200
# no info file in  s15_boss_1434153600
# no info file in  s19_cmb_1552348800
# no info file in  s15_deep56_1430524800
# no info file in  s17_cmb_1504656000
# no info file in  s15_deep8_1446595200
# no info file in  s17_cmb_1494806400
# no info file in  s19_cmb_1554681600
# no info file in  s14_deep56_1414713600
# no info file in  s15_deep56_1438819200
# no info file in  s15_deep8_1433894400
# no info file in  s16_day_02h_s_1480550400
# no info file in  s15_deep56_1434931200
# no info file in  s19_cmb_1568678400
# no info file in  s14_boss_1419379200
# no info file in  s13_deep5_1385683200
# no info file in  s13_deep1_1385942400
# no info file in  s15_boss_1433376000
# no info file in  s15_deep8_1451520000
# no info file in  s16_cmb_1473552000
# no info file in  s17_cmb_1504137600
# no info file in  s15_boss_1448409600
# no info file in  s19_cmb_1563753600
# no info file in  s18_cmb_1538092800
# no info file in  s14_boss_1411344000
# no info file in  s16_cmb_1482105600
# no info file in  s14_deep56_1417046400
# no info file in  s15_deep8_1438300800
# no info file in  s13_deep2_1385424000
# no info file in  s15_deep56_1437264000
# no info file in  s15_boss_1447113600
# no info file in  s15_deep8_1432339200
# no info file in  s15_deep8_1449964800
# no info file in  s19_cmb_1559606400
# no info file in  s16_day_02h_s_1475625600
# no info file in  s15_deep8_1431561600
# no info file in  s15_boss_1449187200
# no info file in  s18_cmb_1539129600
# no info file in  s18_cmb_1525910400
# no info file in  s16_cmb_1464739200
# no info file in  s15_boss_1437264000
# no info file in  s17_cmb_1514764800
# no info file in  s18_cmb_1537574400
# no info file in  s16_cmb_1463961600
# no info file in  s18_cmb_1542499200
# no info file in  s15_boss_1436227200
# no info file in  s13_deep5_1381017600
# no info file in  s17_cmb_1510617600
# no info file in  s16_day_02h_s_1479772800
# no info file in  s14_boss_1414454400
# no info file in  s15_boss_1438300800
# no info file in  s15_boss_1442966400
# no info file in  s16_cmb_1482364800
# no info file in  s15_deep8_1443225600
# no info file in  s15_boss_1442448000
# no info file in  s16_day_02h_s_1476662400
# no info file in  s16_cmb_1476144000
# no info file in  s13_deep5_1384905600
# no info file in  s15_deep56_1448668800
# no info file in  s14_boss_1409788800
# no info file in  s15_deep8_1448150400
# no info file in  s19_cmb_1570233600
# no info file in  s13_deep6_1382054400
# no info file in  s15_boss_1448668800
# no info file in  s19_cmb_1563494400
# no info file in  s15_deep56_1448928000
# no info file in  s19_cmb_1562716800
# no info file in  s13_deep5_1379203200
# no info file in  s15_deep8_1438041600
# no info file in  s13_deep5_1386201600
# no info file in  s18_cmb_1540166400
# no info file in  s14_boss_1415232000
# no info file in  s15_deep56_1437782400
# no info file in  s15_boss_1430524800
# no info file in  s15_deep8_1433376000
# no info file in  s16_cmb_1477440000
# no info file in  s17_cmb_1515283200
# no info file in  s16_day_14h_n_1463961600
# no info file in  s15_deep56_1447891200
# no info file in  s18_cmb_1536537600
# no info file in  s18_cmb_1537056000
# no info file in  s15_boss_1444780800
# no info file in  s16_cmb_1464480000
# no info file in  s15_boss_1438560000
# no info file in  s13_deep5_1383350400
# no info file in  s18_cmb_1527206400
# no info file in  s13_deep1_1382832000
# no info file in  s15_boss_1438041600
# no info file in  s19_cmb_1575158400
# no info file in  s13_deep1_1381795200
# no info file in  s14_deep56_1418860800
# no info file in  s16_day_14h_n_1481068800
# no info file in  s18_cmb_1539907200
# no info file in  s16_day_02h_s_1478995200
# no info file in  s17_cmb_1512691200
# no info file in  s15_deep8_1441670400
# no info file in  s15_boss_1451001600
# no info file in  s15_boss_1448928000
# no info file in  s15_deep8_1436745600
# no info file in  s14_boss_1419897600
# no info file in  s15_boss_1434672000
# no info file in  s14_boss_1414195200
# no info file in  s13_deep6_1386201600
# no info file in  s15_deep9_1438560000
# no info file in  s14_boss_1418083200
# no info file in  s16_cmb_1477958400
# no info file in  s16_day_14h_n_1471219200
# no info file in  s15_boss_1430784000
# no info file in  s15_deep8_1442188800
# no info file in  s16_day_14h_n_1478217600
# no info file in  s15_deep56_1442966400
# no info file in  s16_day_02h_s_1477440000
# no info file in  s15_deep8_1450224000
# no info file in  s13_deep5_1383091200
# no info file in  s16_day_02h_s_1473292800
# no info file in  s13_deep6_1382572800
# no info file in  s13_deep5_1384646400
# no info file in  s16_day_14h_n_1474329600
# no info file in  s15_deep56_1433116800
# no info file in  s17_cmb_1511395200
# no info file in  s13_deep6_1381536000
# no info file in  s16_day_02h_s_1476403200
# no info file in  s14_deep56_1415491200
# no info file in  s17_cmb_1502841600
# no info file in  s16_day_02h_s_1472774400
# no info file in  s16_day_02h_s_1476921600
# no info file in  s15_deep56_1443484800
# no info file in  s14_deep56_1417824000
# no info file in  s14_deep56_1413936000
# no info file in  s15_boss_1444003200
# no info file in  s13_deep6_1386460800
# no info file in  s14_boss_1418601600
# no info file in  s15_boss_1447372800
# no info file in  s16_day_02h_s_1474848000
# no info file in  s17_cmb_1511136000
# no info file in  s16_day_02h_s_1481068800
# no info file in  s16_cmb_1471996800
# no info file in  s14_deep56_1416787200
# no info file in  s15_deep56_1444262400
# no info file in  s16_day_02h_s_1474329600
# no info file in  s15_deep56_1451260800
# no info file in  s19_cmb_1562976000
# no info file in  s14_boss_1414972800
# no info file in  s13_deep2_1386720000
# no info file in  s19_cmb_1554163200
# no info file in  s16_day_02h_s_1479513600
# no info file in  s15_deep56_1452297600
# no info file in  s14_deep56_1410307200
# no info file in  s14_boss_1416009600
# no info file in  s15_boss_1444521600
# no info file in  s15_deep56_1444521600
# no info file in  s15_boss_1439078400
# no info file in  s14_boss_1411603200
# no info file in  s19_cmb_1574121600
# no info file in  s19_cmb_1571011200
# no info file in  s14_deep56_1414195200
# no info file in  s16_day_14h_n_1479513600
# no info file in  s14_deep56_1419379200
# no info file in  s16_day_14h_n_1475625600
# no info file in  s17_cmb_1514246400
# no info file in  s15_deep8_1436486400
# no info file in  s15_deep56_1437523200
# no info file in  s15_deep56_1442707200
# no info file in  s13_deep6_1383609600
# no info file in  s15_boss_1431043200
# no info file in  s14_boss_1416268800
# no info file in  s13_deep6_1381795200
# no info file in  s15_deep8_1442707200
# no info file in  s13_deep1_1383091200
# no info file in  s13_deep2_1385164800
# no info file in  s15_deep8_1451001600
# no info file in  s15_deep56_1433894400
# no info file in  s15_deep9_1434412800
# no info file in  s15_deep9_1438819200
# no info file in  s15_deep8_1431302400
# no info file in  s13_deep1_1385424000
# no info file in  s14_deep56_1411344000
# no info file in  s14_deep56_1418601600
# no info file in  s16_cmb_1465257600
# no info file in  s19_cmb_1573862400
# no info file in  s18_cmb_1540425600
# no info file in  s16_cmb_1474329600
# no info file in  s15_deep56_1449187200
# no info file in  s14_deep56_1411603200
# no info file in  s15_deep8_1449446400
# no info file in  s15_boss_1443225600
# no info file in  s16_cmb_1476662400
# no info file in  s13_deep1_1380499200
# no info file in  s15_boss_1436745600
# no info file in  s15_boss_1442707200
# no info file in  s15_boss_1452038400
# no info file in  s17_cmb_1513209600
# no info file in  s15_deep56_1429488000
# no info file in  s18_cmb_1536278400
# no info file in  s18_cmb_1527465600
# no info file in  s14_deep56_1417564800
# no info file in  s15_deep56_1449964800
# no info file in  s15_boss_1429488000
# no info file in  s13_deep2_1383091200
# no info file in  s15_deep8_1451260800
# no info file in  s14_boss_1419120000
# no info file in  s16_day_14h_n_1474588800
# no info file in  s15_deep56_1432080000
# no info file in  s13_deep1_1385683200
# no info file in  s16_day_02h_s_1472515200
# no info file in  s14_boss_1409529600
# no info file in  s14_deep56_1411862400
# no info file in  s16_day_14h_n_1478476800
# no info file in  s15_boss_1442188800
# no info file in  s15_boss_1449705600
# no info file in  s13_deep6_1383350400
# no info file in  s18_cmb_1541462400
# no info file in  s18_cmb_1543017600
# no info file in  s16_day_02h_s_1475884800
# no info file in  s18_cmb_1540944000
# no info file in  s15_deep56_1449446400
# no info file in  s13_deep6_1386720000
# no info file in  s15_deep9_1442448000
# no info file in  s15_deep56_1447372800
# no info file in  s15_deep8_1430524800
# no info file in  s16_day_14h_n_1481587200
# no info file in  s15_boss_1435968000
# no info file in  s15_deep56_1448150400
# no info file in  s16_day_14h_n_1475107200
# no info file in  s16_day_14h_n_1478995200
# no info file in  s16_day_02h_s_1474070400
# no info file in  s15_deep56_1431561600
# no info file in  s14_deep56_1414972800
# no info file in  s13_deep6_1380758400
# no info file in  s19_cmb_1569974400
# no info file in  s15_boss_1450224000
# no info file in  s15_deep8_1448928000
# no info file in  s15_deep56_1435190400
# no info file in  s18_cmb_1539388800
# no info file in  s14_boss_1413158400
# no info file in  s14_deep56_1413158400
# no info file in  s15_deep8_1447113600
# no info file in  s17_cmb_1515024000
# no info file in  s16_cmb_1473811200
# no info file in  s17_cmb_1509321600
# no info file in  s15_deep8_1431043200
# no info file in  s15_deep56_1439337600
# no info file in  s16_cmb_1472256000
# no info file in  s16_day_02h_s_1464998400
# no info file in  s15_boss_1447891200
# no info file in  s15_deep9_1435968000
# no info file in  s17_cmb_1506470400
# no info file in  s14_deep56_1409788800
# no info file in  s15_boss_1433116800
# no info file in  s18_cmb_1543795200
# no info file in  s16_day_02h_s_1463961600
# no info file in  s15_deep9_1443225600
# no info file in  s18_cmb_1527724800
# no info file in  s13_deep5_1382832000
# no info file in  s18_cmb_1543536000
# no info file in  s17_cmb_1506729600
# no info file in  s15_deep56_1443744000
# no info file in  s15_deep8_1449187200
# no info file in  s13_deep1_1379203200
# no info file in  s14_deep56_1419120000
# no info file in  s16_day_14h_n_1474070400
# no info file in  s15_boss_1447632000
# no info file in  s16_day_14h_n_1480550400
# no info file in  s13_deep2_1384128000
# no info file in  s15_deep8_1446336000
# no info file in  s19_cmb_1555200000
# no info file in  s15_boss_1433635200
# no info file in  s17_cmb_1516060800
# no info file in  s16_day_14h_n_1464220800
# no info file in  s15_deep9_1433894400
# no info file in  s16_cmb_1475884800
# no info file in  s18_cmb_1538611200
# no info file in  s19_cmb_1554940800
# no info file in  s15_deep56_1434672000
# no info file in  s17_cmb_1495324800
# no info file in  s19_cmb_1567123200
# no info file in  s19_cmb_1557014400
# no info file in  s15_deep8_1435708800
# no info file in  s17_cmb_1513987200
# no info file in  s14_deep56_1410048000
# no info file in  s16_day_14h_n_1477958400
# no info file in  s19_cmb_1568419200
# no info file in  s15_boss_1432339200
# no info file in  s17_cmb_1509062400
# no info file in  s19_cmb_1565827200
# no info file in  s16_day_14h_n_1475366400
# no info file in  s17_cmb_1501545600
# no info file in  s19_cmb_1566086400
# no info file in  s15_deep56_1451779200
# no info file in  s16_day_02h_s_1475107200
# no info file in  s16_cmb_1472515200
# no info file in  s14_boss_1417046400
# no info file in  s15_deep56_1435968000
# no info file in  s19_cmb_1567641600
# no info file in  s16_day_02h_s_1473033600
# no info file in  s13_deep5_1380758400
# no info file in  s19_cmb_1560643200
# no info file in  s13_deep6_1382832000
# no info file in  s17_cmb_1510876800
# no info file in  s14_deep56_1416268800
# no info file in  s18_cmb_1541203200
# no info file in  s15_boss_1439596800
# no info file in  s18_cmb_1528502400
# no info file in  s16_day_02h_s_1473552000
# no info file in  s13_deep2_1384387200
# no info file in  s15_deep56_1445558400
# no info file in  s16_cmb_1471219200
# no info file in  s16_day_14h_n_1477180800
# no info file in  s15_deep56_1446076800
# no info file in  s13_deep2_1385942400
# no info file in  s16_day_02h_s_1471996800
# no info file in  s13_deep1_1383350400
# no info file in  s13_deep5_1378684800
# no info file in  s14_deep56_1417305600
# no info file in  s17_cmb_1515542400
# no info file in  s13_deep6_1384387200
# no info file in  s14_boss_1410048000
# no info file in  s15_deep9_1441929600
# no info file in  s17_cmb_1512432000
# no info file in  s16_day_02h_s_1471737600
# no info file in  s13_deep1_1380758400

# %%
table['targetname'][0]
# Out:
# 'Europa (502)'

# %%
path = '/global/cscratch1/sd/jorlo/three_day_maps/'

table = QueryHorizons(time_start='2010-01-01T00:00:00', time_end='2020-01-01T00:00:00', observer_location='W99', step = '1d').queryObjects(['Ceres'])

orbits =  OrbitInterpolator(table)

for  dirname in os.listdir(path=path):
    print(dirname)
    try:
        with h5py.File(path + dirname +"/info.hdf", "r") as hfile:
            #Find the (rough) mjd center of the map
            mjd_cent = hfile["mjd"][()]

    except:
        print('no info file in ', dirname)
        continue
    print(mjd_cent)
    ra, dec, delta = orbits.get_radec_dist(table['targetname'][0], mjd_cent)
    print('ra, dec: ', ra, dec)
    
    hdu = fits.open(path + dirname + '/kmap.fits')
    w = wcs.WCS(hdu[0].header)
    
    c = SkyCoord(ra, dec, unit="deg")
    x, y = w.world_to_pixel(c)
    print(x,y)
    kmap = enmap.read_map(path + dirname + '/kmap.fits')
    try:
        fmap = enmap.read_map(path + dirname + '/frhs.fits')
    except: continue
    plt.imshow(kmap)
    plt.plot(x,y, color='red', marker='+')
    plt.show()
    plt.close()

    plt.imshow(fmap[int(y-50):int(y+50),int(x-50):int(x+50)])
    plt.show()
    plt.close()
# Out:
# 0
# s18_cmb_1541462400
# 58429.52446208872
# ra, dec:  208.23085462296157 -4.415826753130108
# 19905.89872262212 3514.8003948121986
# s18_cmb_1536537600
# 58372.61756241674
# ra, dec:  184.9227856100031 5.911162180993855
# 21304.3828633996 4134.419730859624
# s18_cmb_1538352000
# 58393.569296172536
# ra, dec:  193.46776000222982 1.929181018697992
# 20791.68439986601 3895.5008611218773
# WARNING: File may have been truncated: actual file length (166920192) is smaller than the expected size (445826880) [astropy.io.fits.file]
# s18_cmb_1543795200
# 58456.50656068883
# ra, dec:  219.22835862956742 -8.477559681136889
# 19246.048482225786 3271.0964191317967
# s18_cmb_1528243200
# 58276.8507168194
# ra, dec:  147.69325835099139 23.226609407237095
# 1938.1544989406939 5173.346564434198
# s18_cmb_1525651200
# 58246.46727990333
# ra, dec:  138.02818270924314 27.417208395838124
# 2518.059037445577 5424.782503750254
# /tmp/ipykernel_46468/3499126242.py:36: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
#   plt.imshow(fmap[int(y-50):int(y+50),int(x-50):int(x+50)])
# s18_cmb_1527465600
# 58267.50927254574
# ra, dec:  144.49574693032235 24.61133586614251
# 2130.0051841808327 5256.430151968521
# /tmp/ipykernel_46468/3499126242.py:36: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
#   plt.imshow(fmap[int(y-50):int(y+50),int(x-50):int(x+50)])
# s18_cmb_1527206400
# 58264.98967472778
# ra, dec:  143.66190260349546 24.97095596661909
# 2180.035843790445 5278.007357997116
# /tmp/ipykernel_46468/3499126242.py:36: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
#   plt.imshow(fmap[int(y-50):int(y+50),int(x-50):int(x+50)])
# s18_cmb_1544313600
# 58462.03530593746
# ra, dec:  221.44766154441157 -9.213978588284869
# 19112.89030733514 3226.911284702919
# s18_cmb_1527984000
# 58273.24477721383
# ra, dec:  146.44026652662848 23.770653149855995
# 2013.3340084024676 5205.9891889913315
# s18_cmb_1540166400
# 58414.73956544741
# ra, dec:  202.1554774423525 -1.9098374924643804
# 20270.42135345866 3665.1597504521396
# s18_cmb_1536796800
# 58375.41006159657
# ra, dec:  186.05805485619464 5.374127670406174
# 21236.266708628114 4102.197660224364
# s18_cmb_1537056000
# 58378.489483829275
# ra, dec:  187.31134271005678 4.7835932157528775
# 21161.069437396385 4066.765592945167
# s18_cmb_1543536000
# 58453.863463292975
# ra, dec:  218.16166001708862 -8.113271725907094
# 19310.050398974512 3292.9536964455842
# s18_cmb_1539388800
# 58405.494640098885
# ra, dec:  198.35791933180008 -0.2643157690813206
# 20498.274840091803 3763.8910538551213
# s18_cmb_1527724800
# 58270.54465643587
# ra, dec:  145.51708916154269 24.17023345428045
# 2068.724650307613 5229.964007256798
# /tmp/ipykernel_46468/3499126242.py:36: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
#   plt.imshow(fmap[int(y-50):int(y+50),int(x-50):int(x+50)])
# s18_cmb_1543276800
# 58450.39318566434
# ra, dec:  216.75641430992448 -7.62308555001406
# 19394.36514140436 3322.3648669991653

# %%
path = '/home/r/rbond/sigurdkn/scratch/actpol/planet9/20200801/maps/combined/'


with h5py.File(path + 's18_cmb_1536796800' +"/info.hdf", "r") as hfile:
    #Find the (rough) mjd center of the map
    mjd_cent = hfile["mjd"][()]
    print(hfile['mjd'][()])
# Out:
# 58375.41006159657
